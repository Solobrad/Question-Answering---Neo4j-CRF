# %% [markdown]
# # Load the Rebel model and tokenizer

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import math
import torch
from docx import Document
import os
import pickle
import subprocess
import re
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the Rebel model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("Babelscape/rebel-large")
model = AutoModelForSeq2SeqLM.from_pretrained("Babelscape/rebel-large")

corenlp_directory = 'stanford-corenlp-4.5.7'
temp_txt_files_directory = 'temp_txt_files'
# Out:
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# # Define a class to manage the knowledge base (KB)

# %%
# Define a class to manage the knowledge base (KB)
class KB:
    def __init__(self):
        self.entities = {}
        self.relations = []
        self.sources = {}

    def merge_with_kb(self, kb2):
        for r in kb2.relations:
            self.add_relation(r)

    def are_relations_equal(self, r1, r2):
        return all(r1[attr] == r2[attr] for attr in ["head", "type", "tail"])

    def exists_relation(self, r1):
        return any(self.are_relations_equal(r1, r2) for r2 in self.relations)

    def merge_relations(self, r2):
        r1 = [r for r in self.relations if self.are_relations_equal(r2, r)][0]
        spans_to_add = [span for span in r2["meta"]["spans"]
                        if span not in r1["meta"]["spans"]]
        r1["meta"]["spans"] += spans_to_add

    def add_entity(self, e):
        self.entities[e["title"]] = {k: v for k, v in e.items() if k != "title"}

    def add_relation(self, r):
        candidate_entities = [r["head"], r["tail"]]
        entities = [{"title": ent} for ent in candidate_entities]

        for e in entities:
            self.add_entity(e)

        r["head"] = entities[0]["title"]
        r["tail"] = entities[1]["title"]

        if not self.exists_relation(r):
            self.relations.append(r)
        else:
            self.merge_relations(r)

    def print(self):
        print("Entities:")
        for e in self.entities.items():
            print(f"  {e}")
        print("Relations:")
        for r in self.relations:
            print(f"  {r}")
        print("Sources:")
        for s in self.sources.items():
            print(f"  {s}")


# Function to extract relations from model output
def extract_relations_from_text(text):
    relations = []
    relation, subject, relation, object_ = '', '', '', ''
    text = text.strip()
    current = 'x'
    text_replaced = text.replace("<s>", "").replace("<pad>", "").replace("</s>", "")
    for token in text_replaced.split():
        if token == "<triplet>":
            current = 't'
            if relation != '':
                relations.append({
                    'head': subject.strip(),
                    'type': relation.strip(),
                    'tail': object_.strip()
                })
                relation = ''
            subject = ''
        elif token == "<subj>":
            current = 's'
            if relation != '':
                relations.append({
                    'head': subject.strip(),
                    'type': relation.strip(),
                    'tail': object_.strip()
                })
            object_ = ''
        elif token == "<obj>":
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and relation != '' and object_ != '':
        relations.append({
            'head': subject.strip(),
            'type': relation.strip(),
            'tail': object_.strip()
        })
    return relations










# Function to process a single document file
def process_document(file_path):
    try:
        doc = Document(file_path)
        
        # Extract text
        text = "\n".join(paragraph.text for paragraph in doc.paragraphs)

        # Print text type
        print(f"Text type: {type(text)}")  # Should be <class 'str'>

        # Convert text to KB
        kb = from_text_to_kb(text, span_length=128, verbose=False)
        return kb

    except Exception as e:
        print(f"Error processing {file_path}: {str(e)}")
        return None


# Function to convert text to KB (Knowledge Base)


def from_text_to_kb(text, span_length=128, verbose=False, extend_kb=None):
    
    # Tokenize whole text
    inputs = tokenizer([text], return_tensors="pt")
    
    # Compute span boundaries
    num_tokens = len(inputs["input_ids"][0])
    if verbose:
        print(f"Input has {num_tokens} tokens")
    num_spans = math.ceil(num_tokens / span_length)
    if verbose:
        print(f"Input has {num_spans} spans")
    overlap = math.ceil((num_spans * span_length - num_tokens) / max(num_spans - 1, 1))
    spans_boundaries = []
    start = 0
    for i in range(num_spans):
        end = start + span_length
        # Ensure end does not exceed the number of tokens
        if end > num_tokens:
            end = num_tokens
        spans_boundaries.append([start, end])
        start = end - overlap
        # Ensure start does not go negative
        if start < 0:
            start = 0
    if verbose:
        print(f"Span boundaries are {spans_boundaries}")

    # Transform input with spans
    tensor_ids = []
    tensor_masks = []
    for boundary in spans_boundaries:
        start, end = boundary
        if start < num_tokens and end <= num_tokens:
            tensor_ids.append(inputs["input_ids"][0][start:end])
            tensor_masks.append(inputs["attention_mask"][0][start:end])

    # Check if we have tensors to stack
    if not tensor_ids or not tensor_masks:
        raise ValueError("No valid spans found to create tensors.")

    inputs = {
        "input_ids": torch.stack(tensor_ids),
        "attention_mask": torch.stack(tensor_masks)
    }

    # Generate relations
    num_return_sequences = 3
    gen_kwargs = {
        "max_length": 512,
        "length_penalty": 0,
        "num_beams": 3,
        "num_return_sequences": num_return_sequences
    }
    generated_tokens = model.generate(**inputs, **gen_kwargs)
    
    # Decode relations
    decoded_preds = tokenizer.batch_decode(generated_tokens, skip_special_tokens=False)

    # Create KB
    if extend_kb is None:
        kb = KB()
    else:
        kb = extend_kb

    i = 0
    for sentence_pred in decoded_preds:
        current_span_index = i // num_return_sequences
        relations = extract_relations_from_text(sentence_pred)
        for relation in relations:
            relation["meta"] = {
                "spans": [spans_boundaries[current_span_index]]
            }
            kb.add_relation(relation)
        i += 1

    return kb

# %% [markdown]
# # Function to save KB to a pickle file

# %%
# Function to save KB to a pickle file
def save_kb(kb, filename):
    save_folder = "Saved_Knowledge/"
    if not os.path.exists(save_folder):
        os.makedirs(save_folder)
    # Print entities and relations before saving

    print("Relations before saving:", kb.relations)
    
    with open(os.path.join(save_folder, filename), "wb") as f:
        pickle.dump(kb, f)
    print(f"KB saved to '{filename}'")

# Main script to process all .docx files in the current directory
def main():
    # Update this path to the directory wheremarie your .docx files are stored
    directory = 'Marie Curie doc/'  # Replace with your directory path

    for filename in os.listdir(directory):
        if filename.endswith('.docx'):
            file_path = os.path.join(directory, filename)
            kb = process_document(file_path)
            if kb:
                save_kb(kb, f"{filename.split('.')[0]}.pkl")
                print(f"Processed '{filename}' and saved KB.")


if __name__ == "__main__":
    main()
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1384 > 1024). Running this sequence through the model will result in indexing errors
# Text type: <class 'str'>
# Relations before saving: [{'head': 'Marie Curie', 'type': 'spouse', 'tail': 'Pierre Curie', 'meta': {'spans': [[0, 128]]}}, {'head': 'Pierre Curie', 'type': 'spouse', 'tail': 'Marie Curie', 'meta': {'spans': [[0, 128]]}}, {'head': 'Kingdom of Poland', 'type': 'capital', 'tail': 'Warsaw', 'meta': {'spans': [[125, 253]]}}, {'head': 'Kingdom of Poland', 'type': 'country', 'tail': 'Russian Empire', 'meta': {'spans': [[125, 253]]}}, {'head': 'Kingdom of Poland', 'type': 'located in the administrative territorial entity', 'tail': 'Russian Empire', 'meta': {'spans': [[125, 253]]}}, {'head': 'Pierre Curie', 'type': 'place of death', 'tail': 'Paris', 'meta': {'spans': [[250, 378]]}}, {'head': 'Henri Becquerel', 'type': 'place of death', 'tail': 'Paris', 'meta': {'spans': [[250, 378]]}}, {'head': 'Pierre Curie', 'type': 'place of death', 'tail': 'Paris street accident', 'meta': {'spans': [[250, 378]]}}, {'head': 'Henri Becquerel', 'type': 'place of death', 'tail': 'Paris street accident', 'meta': {'spans': [[250, 378]]}}, {'head': 'polonium', 'type': 'discoverer or inventor', 'tail': 'Marie Curie', 'meta': {'spans': [[250, 378], [375, 503]]}}, {'head': 'radium', 'type': 'discoverer or inventor', 'tail': 'Marie Curie', 'meta': {'spans': [[250, 378]]}}, {'head': 'polonium', 'type': 'instance of', 'tail': 'chemical element', 'meta': {'spans': [[375, 503]]}}, {'head': 'Marie Curie', 'type': 'work location', 'tail': 'Paris', 'meta': {'spans': [[375, 503]]}}, {'head': 'Passy', 'type': 'located in the administrative territorial entity', 'tail': 'Haute-Savoie', 'meta': {'spans': [[500, 628]]}}, {'head': 'Passy', 'type': 'country', 'tail': 'France', 'meta': {'spans': [[500, 628]]}}, {'head': 'Haute-Savoie', 'type': 'country', 'tail': 'France', 'meta': {'spans': [[500, 628]]}}, {'head': 'International Year of Chemistry', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[500, 628]]}}, {'head': 'Marie Curie Skłodowska', 'type': 'place of birth', 'tail': 'Warsaw', 'meta': {'spans': [[625, 753]]}}, {'head': 'Marie Curie Skłodowska', 'type': 'date of birth', 'tail': '7 November 1867', 'meta': {'spans': [[625, 753]]}}, {'head': 'Marie Curie Skłodowska', 'type': 'mother', 'tail': 'Bronisława, née Boguska', 'meta': {'spans': [[625, 753]]}}, {'head': 'Marie Curie Skłodowska', 'type': 'father', 'tail': 'Władysław Skłodowski', 'meta': {'spans': [[625, 753]]}}, {'head': 'Congress Poland', 'type': 'capital', 'tail': 'Warsaw', 'meta': {'spans': [[625, 753]]}}, {'head': 'Congress Poland', 'type': 'country', 'tail': 'Russian Empire', 'meta': {'spans': [[625, 753]]}}, {'head': 'Bronisława, née Boguska', 'type': 'child', 'tail': 'Marie Curie Skłodowska', 'meta': {'spans': [[625, 753]]}}, {'head': 'Bronisława, née Boguska', 'type': 'spouse', 'tail': 'Władysław Skłodowski', 'meta': {'spans': [[625, 753]]}}, {'head': 'Congress Poland', 'type': 'located in the administrative territorial entity', 'tail': 'Russian Empire', 'meta': {'spans': [[625, 753]]}}, {'head': 'Władysław Skłodowski', 'type': 'child', 'tail': 'Marie Curie Skłodowska', 'meta': {'spans': [[625, 753]]}}, {'head': 'Władysław Skłodowski', 'type': 'spouse', 'tail': 'Bronisława, née Boguska', 'meta': {'spans': [[625, 753]]}}, {'head': 'January Uprising', 'type': 'point in time', 'tail': '1863', 'meta': {'spans': [[750, 878]]}}, {'head': 'Marie Curie', 'type': 'sibling', 'tail': 'Marie Curie', 'meta': {'spans': [[750, 878]]}}, {'head': 'Bolesław Prus', 'type': 'place of birth', 'tail': 'Lublin', 'meta': {'spans': [[875, 1003]]}}, {'head': 'Bolesław Prus', 'type': 'work location', 'tail': 'Lublin', 'meta': {'spans': [[875, 1003]]}}, {'head': 'Marie Curie', 'type': 'field of work', 'tail': 'mathematics', 'meta': {'spans': [[875, 1003]]}}, {'head': 'Marie Curie', 'type': 'field of work', 'tail': 'physics', 'meta': {'spans': [[875, 1003]]}}, {'head': 'Zofia', 'type': 'mother', 'tail': 'Bronisława', 'meta': {'spans': [[1000, 1128]]}}, {'head': 'Marie Curie', 'type': 'mother', 'tail': 'Bronisława', 'me ...
# KB saved to 'Marie Curie 1.pkl'
# Processed 'Marie Curie 1.docx' and saved KB.
# Text type: <class 'str'>
# Relations before saving: [{'head': 'Kazimierz Żorie', 'type': 'family', 'tail': 'Żorawskis', 'meta': {'spans': [[0, 128]]}}, {'head': 'Kazimierz Żorie', 'type': 'place of birth', 'tail': 'Szczuki', 'meta': {'spans': [[0, 128]]}}, {'head': 'Kazimierz Żorąskis', 'type': 'family', 'tail': 'Żorawskis', 'meta': {'spans': [[0, 128]]}}, {'head': 'Kazimierz Żorawski', 'type': 'educated at', 'tail': 'Kraków University', 'meta': {'spans': [[117, 245]]}}, {'head': 'Kazimierz Żorawski', 'type': 'employer', 'tail': 'Kraków University', 'meta': {'spans': [[117, 245]]}}, {'head': 'Kazimierz Żorawski', 'type': 'occupation', 'tail': 'mathematician', 'meta': {'spans': [[117, 245]]}}, {'head': 'Radium Institute', 'type': 'inception', 'tail': '1932', 'meta': {'spans': [[234, 362]]}}, {'head': 'statue of Marie Curie Skłodowska', 'type': 'inception', 'tail': '1935', 'meta': {'spans': [[234, 362]]}}, {'head': 'Flying University', 'type': 'located in the administrative territorial entity', 'tail': 'Warsaw', 'meta': {'spans': [[351, 479]]}}, {'head': 'Marie Curie Skłodowska', 'type': 'place of birth', 'tail': 'Warsaw', 'meta': {'spans': [[351, 479]]}}, {'head': 'Marie Curie Skłodowska', 'type': 'work location', 'tail': 'Warsaw', 'meta': {'spans': [[351, 479]]}}, {'head': 'Museum of Industry and Agriculture', 'type': 'located in the administrative territorial entity', 'tail': 'Krakowskie Przedmieście', 'meta': {'spans': [[468, 596]]}}, {'head': 'Museum of Industry and Agriculture', 'type': 'located in the administrative territorial entity', 'tail': 'Warsaw', 'meta': {'spans': [[468, 596]]}}, {'head': 'Old Town', 'type': 'located in the administrative territorial entity', 'tail': 'Warsaw', 'meta': {'spans': [[468, 596]]}}, {'head': 'Marie Curie', 'type': 'educated at', 'tail': 'University of Paris', 'meta': {'spans': [[585, 713]]}}, {'head': 'Latin Quarter', 'type': 'part of', 'tail': 'University of Paris', 'meta': {'spans': [[585, 713]]}}, {'head': 'Gabriel Lippmann', 'type': 'employer', 'tail': 'University of Paris', 'meta': {'spans': [[702, 830]]}}, {'head': 'Gabriel Lippmann', 'type': 'educated at', 'tail': 'University of Paris', 'meta': {'spans': [[702, 830]]}}, {'head': 'Gabriel Lippmann', 'type': 'field of work', 'tail': 'physics', 'meta': {'spans': [[702, 830]]}}, {'head': 'Józef Wierusz-Kowalski', 'type': 'educated at', 'tail': 'The City of Paris Industrial Physics and Chemistry Higher Educational Institution', 'meta': {'spans': [[819, 947]]}}, {'head': 'Józef Wierusz-Kowalski', 'type': 'educated at', 'tail': 'The City of Paris Industrial Physics and Chemistry Higher Educational Institution (ESPCI Paris)', 'meta': {'spans': [[819, 947]]}}, {'head': 'Industrial Physics and Chemistry Higher Educational Institution', 'type': 'located in the administrative territorial entity', 'tail': 'Paris', 'meta': {'spans': [[819, 947]]}}, {'head': 'Pierre Curie and Marie Skłodowska-Curie, 1895', 'type': 'point in time', 'tail': '1895', 'meta': {'spans': [[936, 1064]]}}, {'head': 'Pierre Curie', 'type': 'spouse', 'tail': 'Marie Skłodowska-Curie', 'meta': {'spans': [[936, 1064]]}}, {'head': 'Marie Skłodowska-Curie', 'type': 'spouse', 'tail': 'Pierre Curie', 'meta': {'spans': [[936, 1064]]}}, {'head': 'Pierre Curie and Marie Skłodowska-Curie, 1895', 'type': 'publication date', 'tail': '1895', 'meta': {'spans': [[936, 1064]]}}, {'head': 'Kraków University', 'type': 'country', 'tail': 'Poland', 'meta': {'spans': [[1053, 1181]]}}, {'head': 'Kraków University', 'type': 'located in the administrative territorial entity', 'tail': 'Warsaw', 'meta': {'spans': [[1053, 1181]]}}, {'head': 'Kraków University', 'type': 'location', 'tail': 'Warsaw', 'meta': {'spans': [[1053, 1181]]}}, {'head': 'Pierre Curie', 'type': 'spouse', 'tail': 'Marie Curie', 'meta': {'spans': [[1170, 1298]]}}, {'head': 'Marie Curie', 'type': 'spouse', 'tail': 'Pierre Curie', 'meta': {'spans': [[1170, 1298]]}}, {'head': 'Pierre Curie', 'type': 'place of death', 'tail': 'Sceaux', 'meta': {'spans': [[1170 ...
# KB saved to 'Marie Curie 2.pkl'
# Processed 'Marie Curie 2.docx' and saved KB.
# Text type: <class 'str'>
# Relations before saving: [{'head': 'electrometer', 'type': 'discoverer or inventor', 'tail': 'Pierre Curie', 'meta': {'spans': [[0, 128]]}}, {'head': 'electrometer', 'type': 'named after', 'tail': 'Pierre Curie', 'meta': {'spans': [[0, 128]]}}, {'head': 'Irène', 'type': 'educated at', 'tail': 'École Normale Supérieure', 'meta': {'spans': [[123, 251]]}}, {'head': 'Marie Curie', 'type': 'child', 'tail': 'Irène', 'meta': {'spans': [[123, 251]]}}, {'head': 'Irène', 'type': 'mother', 'tail': 'Marie Curie', 'meta': {'spans': [[123, 251]]}}, {'head': 'Marie Curie', 'type': 'educated at', 'tail': 'École Normale Supérieure', 'meta': {'spans': [[123, 251]]}}, {'head': 'pitchblende', 'type': 'subclass of', 'tail': 'uranium', 'meta': {'spans': [[246, 374]]}}, {'head': 'torbernite', 'type': 'subclass of', 'tail': 'uranium', 'meta': {'spans': [[246, 374]]}}, {'head': 'pitchblende', 'type': 'named after', 'tail': 'uranium', 'meta': {'spans': [[246, 374]]}}, {'head': 'torbernite', 'type': 'named after', 'tail': 'uranium', 'meta': {'spans': [[246, 374]]}}, {'head': 'thorium', 'type': 'instance of', 'tail': 'element', 'meta': {'spans': [[369, 497], [861, 989]]}}, {'head': 'thorium', 'type': 'discoverer or inventor', 'tail': 'Marie Curie', 'meta': {'spans': [[369, 497]]}}, {'head': 'Pierre Curie', 'type': 'field of work', 'tail': 'crystals', 'meta': {'spans': [[492, 620]]}}, {'head': 'Marie Curie’s biography of Marie Curie’s husband', 'type': 'author', 'tail': 'Marie Curie', 'meta': {'spans': [[492, 620]]}}, {'head': 'Marie Curie’s biography of Marie Curie’s husband', 'type': 'main subject', 'tail': 'Marie Curie', 'meta': {'spans': [[492, 620]]}}, {'head': 'Henri Becquerel', 'type': 'member of', 'tail': 'Academia', 'meta': {'spans': [[615, 743]]}}, {'head': 'Pierre', 'type': 'sibling', 'tail': 'Irène', 'meta': {'spans': [[615, 743]]}}, {'head': 'Irène', 'type': 'sibling', 'tail': 'Pierre', 'meta': {'spans': [[615, 743]]}}, {'head': 'Gabriel Lippmann', 'type': 'member of', 'tail': 'Académie des Sciences', 'meta': {'spans': [[738, 866]]}}, {'head': 'Henri Becquerel', 'type': 'member of', 'tail': 'Académie des Sciences', 'meta': {'spans': [[738, 866]]}}, {'head': 'his own finding', 'type': 'author', 'tail': 'Gerhard Carl Schmidt', 'meta': {'spans': [[861, 989]]}}, {'head': 'his own finding', 'type': 'named after', 'tail': 'Gerhard Carl Schmidt', 'meta': {'spans': [[861, 989]]}}, {'head': 'uranium', 'type': 'instance of', 'tail': 'element', 'meta': {'spans': [[984, 1112]]}}, {'head': 'Marie Curie', 'type': 'spouse', 'tail': 'Pierre Curie', 'meta': {'spans': [[984, 1112]]}}, {'head': 'Pierre Curie', 'type': 'spouse', 'tail': 'Marie Curie', 'meta': {'spans': [[984, 1112]]}}, {'head': 'uranium', 'type': 'discoverer or inventor', 'tail': 'Marie Curie', 'meta': {'spans': [[984, 1112]]}}, {'head': 'polonium', 'type': 'named after', 'tail': 'Poland', 'meta': {'spans': [[1107, 1235]]}}, {'head': 'radium', 'type': 'publication date', 'tail': '26 December 1898', 'meta': {'spans': [[1107, 1235]]}}, {'head': 'Radium', 'type': 'instance of', 'tail': 'element', 'meta': {'spans': [[1107, 1235]]}}, {'head': 'bismuth', 'type': 'instance of', 'tail': 'element', 'meta': {'spans': [[1230, 1358]]}}, {'head': 'radium', 'type': 'instance of', 'tail': 'element', 'meta': {'spans': [[1230, 1358]]}}, {'head': 'barium', 'type': 'instance of', 'tail': 'element', 'meta': {'spans': [[1230, 1358]]}}]
# KB saved to 'Marie Curie 3.pkl'
# Processed 'Marie Curie 3.docx' and saved KB.
# Text type: <class 'str'>
# Relations before saving: [{'head': 'radium chloride', 'type': 'has part', 'tail': 'radium', 'meta': {'spans': [[0, 128]]}}, {'head': 'radium', 'type': 'discoverer or inventor', 'tail': 'Marie Curie', 'meta': {'spans': [[0, 128], [1080, 1208]]}}, {'head': 'Gabriel Lippmann', 'type': 'employer', 'tail': 'University of Paris', 'meta': {'spans': [[120, 248]]}}, {'head': 'Gabriel Lippmann', 'type': 'educated at', 'tail': 'University of Paris', 'meta': {'spans': [[120, 248]]}}, {'head': 'Pierre Curie', 'type': 'member of', 'tail': 'Royal Swedish Academy of Sciences', 'meta': {'spans': [[240, 368]]}}, {'head': 'Pierre Curie', 'type': 'award received', 'tail': 'Nobel Prize in Physics', 'meta': {'spans': [[240, 368], [360, 488]]}}, {'head': 'Marie Curie', 'type': 'member of', 'tail': 'Royal Swedish Academy of Sciences', 'meta': {'spans': [[240, 368]]}}, {'head': 'Marie Curie', 'type': 'award received', 'tail': 'Nobel Prize in Physics', 'meta': {'spans': [[240, 368], [360, 488]]}}, {'head': 'Henri Becquerel', 'type': 'member of', 'tail': 'Royal Swedish Academy of Sciences', 'meta': {'spans': [[240, 368]]}}, {'head': 'Henri Becquerel', 'type': 'award received', 'tail': 'Nobel Prize in Physics', 'meta': {'spans': [[240, 368], [360, 488]]}}, {'head': 'Nobel Prize in Physics', 'type': 'conferred by', 'tail': 'Royal Swedish Academy of Sciences', 'meta': {'spans': [[240, 368]]}}, {'head': 'Pierre Curie', 'type': 'award received', 'tail': 'Nobel Prize in Physics, Physics, and Henri Becquerel', 'meta': {'spans': [[240, 368]]}}, {'head': 'Marie Curie', 'type': 'award received', 'tail': 'Nobel Prize in Physics, Physics, and Henri Becquerel', 'meta': {'spans': [[240, 368]]}}, {'head': 'Henri Becquerel', 'type': 'award received', 'tail': 'Nobel Prize in Physics, Physics, and Henri Becquerel', 'meta': {'spans': [[240, 368]]}}, {'head': 'Marie Curie', 'type': 'spouse', 'tail': 'Pierre Curie', 'meta': {'spans': [[480, 608]]}}, {'head': 'Pierre Curie', 'type': 'spouse', 'tail': 'Marie Curie', 'meta': {'spans': [[480, 608]]}}, {'head': 'Marie Curie', 'type': 'child', 'tail': 'Ève', 'meta': {'spans': [[600, 728]]}}, {'head': 'Ève', 'type': 'mother', 'tail': 'Marie Curie', 'meta': {'spans': [[600, 728]]}}, {'head': 'Pierre Curie', 'type': 'date of death', 'tail': '19 April 1906', 'meta': {'spans': [[720, 848]]}}, {'head': 'Pierre Curie was killed in a road accident', 'type': 'point in time', 'tail': '19 April 1906', 'meta': {'spans': [[720, 848]]}}, {'head': 'Radium Institute', 'type': 'parent organization', 'tail': 'Pasteur Institute', 'meta': {'spans': [[840, 968]]}}, {'head': 'Pasteur Institute', 'type': 'subsidiary', 'tail': 'Radium Institute', 'meta': {'spans': [[840, 968]]}}, {'head': 'Marie Curie', 'type': 'employer', 'tail': 'University of Paris', 'meta': {'spans': [[840, 968]]}}, {'head': 'Marie Curie', 'type': 'educated at', 'tail': 'University of Paris', 'meta': {'spans': [[840, 968]]}}, {'head': 'Pierre Paul Émile Roux', 'type': 'employer', 'tail': 'Pasteur Institute', 'meta': {'spans': [[960, 1088]]}}, {'head': 'Pasteur Institute', 'type': 'founded by', 'tail': 'Pierre Paul Émile Roux', 'meta': {'spans': [[960, 1088]]}}, {'head': 'curie', 'type': 'named after', 'tail': 'Marie Curie', 'meta': {'spans': [[1080, 1208]]}}, {'head': 'Marguerite Perey', 'type': 'member of', 'tail': 'French Academy of Sciences', 'meta': {'spans': [[1200, 1328]]}}, {'head': 'Guglielmo Marconi', 'type': 'notable work', 'tail': 'wireless telegraph', 'meta': {'spans': [[1200, 1328]]}}, {'head': 'wireless telegraph', 'type': 'discoverer or inventor', 'tail': 'Guglielmo Marconi', 'meta': {'spans': [[1200, 1328]]}}]
# KB saved to 'Marie Curie 4.pkl'
# Processed 'Marie Curie 4.docx' and saved KB.
# Text type: <class 'str'>
# Relations before saving: [{'head': 'Paul Langevin', 'type': 'student of', 'tail': 'Pierre Curie', 'meta': {'spans': [[0, 128]]}}, {'head': 'Pierre Curie', 'type': 'student', 'tail': 'Paul Langevin', 'meta': {'spans': [[0, 128]]}}, {'head': 'Paul Langevin', 'type': 'student of', 'tail': "Pierre Curie's", 'meta': {'spans': [[0, 128]]}}, {'head': "Pierre Curie's", 'type': 'student', 'tail': 'Paul Langevin', 'meta': {'spans': [[0, 128]]}}, {'head': 'Paul Langevin', 'type': 'award received', 'tail': 'Nobel Prize', 'meta': {'spans': [[120, 248]]}}, {'head': 'Nobel Prize', 'type': 'winner', 'tail': 'Paul Langevin', 'meta': {'spans': [[120, 248]]}}, {'head': 'Paul Langevin', 'type': 'award received', 'tail': 'Nobel Prize diploma', 'meta': {'spans': [[120, 248]]}}, {'head': 'Royal Swedish Academy of Sciences', 'type': 'award received', 'tail': 'Nobel Prize in Chemistry', 'meta': {'spans': [[240, 368]]}}, {'head': '1911 Nobel Prize in Chemistry', 'type': 'conferred by', 'tail': 'Royal Swedish Academy of Sciences', 'meta': {'spans': [[240, 368]]}}, {'head': '1911 Nobel Prize in Chemistry', 'type': 'point in time', 'tail': '1911', 'meta': {'spans': [[240, 368]]}}, {'head': 'Svante Arrheniusiusius', 'type': 'member of', 'tail': 'Royal Swedish Academy of Sciences', 'meta': {'spans': [[240, 368]]}}, {'head': 'Svante Arrheniusiusius', 'type': 'award received', 'tail': 'Nobel Prize in Chemistry', 'meta': {'spans': [[240, 368]]}}, {'head': 'Svante Arrheniusius', 'type': 'member of', 'tail': 'Royal Swedish Academy of Sciences', 'meta': {'spans': [[240, 368]]}}, {'head': 'Svante Arrheniusius', 'type': 'award received', 'tail': 'Nobel Prize in Chemistry', 'meta': {'spans': [[240, 368]]}}, {'head': 'two Nobel Prizes', 'type': 'is a list of', 'tail': 'two', 'meta': {'spans': [[360, 488]]}}, {'head': 'two Nobel Prizes', 'type': 'has part', 'tail': 'two', 'meta': {'spans': [[360, 488]]}}, {'head': 'two', 'type': 'part of', 'tail': 'two Nobel Prizes', 'meta': {'spans': [[360, 488]]}}, {'head': 'Radium Institute', 'type': 'inception', 'tail': '1914', 'meta': {'spans': [[480, 608]]}}, {'head': 'Linus Pauling', 'type': 'employer', 'tail': 'Radium Institute', 'meta': {'spans': [[480, 608]]}}, {'head': 'Warsaw Scientific Society', 'type': 'located in the administrative territorial entity', 'tail': 'Warsaw', 'meta': {'spans': [[600, 728]]}}, {'head': 'Radium Institute', 'type': 'parent organization', 'tail': 'Warsaw Scientific Society', 'meta': {'spans': [[600, 728]]}}, {'head': 'Radium Institute', 'type': 'located in the administrative territorial entity', 'tail': 'Warsaw', 'meta': {'spans': [[600, 728]]}}, {'head': 'Marie Curie', 'type': 'employer', 'tail': 'University of Paris', 'meta': {'spans': [[720, 848]]}}, {'head': 'Marie Curie', 'type': 'employer', 'tail': 'Radium Institute of the University of Paris', 'meta': {'spans': [[720, 848]]}}, {'head': 'Marie Curie', 'type': 'conflict', 'tail': 'World War I', 'meta': {'spans': [[720, 848]]}}, {'head': 'French Army', 'type': 'conflict', 'tail': 'World War I', 'meta': {'spans': [[720, 848]]}}, {'head': 'petites Curies', 'type': 'discoverer or inventor', 'tail': 'Marie Curie', 'meta': {'spans': [[840, 968]]}}, {'head': 'Marie Curie', 'type': 'employer', 'tail': 'Red Cross Radiology Service', 'meta': {'spans': [[840, 968]]}}, {'head': 'radon', 'type': 'has part', 'tail': 'radium', 'meta': {'spans': [[960, 1088]]}}, {'head': 'radon', 'type': 'named after', 'tail': 'radium', 'meta': {'spans': [[960, 1088]]}}, {'head': 'Marie Curie', 'type': 'child', 'tail': 'Irène', 'meta': {'spans': [[960, 1088]]}}, {'head': 'Marie Curie', 'type': 'award received', 'tail': 'Nobel Prize', 'meta': {'spans': [[1080, 1208], [1200, 1328]]}}, {'head': "Marie Curie's X-ray units", 'type': 'named after', 'tail': 'Marie Curie', 'meta': {'spans': [[1080, 1208]]}}, {'head': 'Nobel Prize', 'type': 'winner', 'tail': 'Marie Curie', 'meta': {'spans': [[1200, 1328]]}}]
# KB saved to 'Marie Curie 5.pkl'
# Processed 'Marie Curie 5.docx' and saved KB.
# Text type: <class 'str'>
# Relations before saving: [{'head': 'Radiology in War', 'type': 'author', 'tail': 'Marie Curie', 'meta': {'spans': [[0, 128]]}}, {'head': 'stipend for Marie Curie', 'type': 'inception', 'tail': '1920', 'meta': {'spans': [[0, 128]]}}, {'head': 'Warren G. Harding', 'type': 'residence', 'tail': 'White House', 'meta': {'spans': [[122, 250]]}}, {'head': 'Warren G. Harding', 'type': 'spouse', 'tail': 'First Lady', 'meta': {'spans': [[122, 250]]}}, {'head': 'First Lady', 'type': 'spouse', 'tail': 'Warren G. Harding', 'meta': {'spans': [[122, 250]]}}, {'head': 'Marie Curie Radium Fund', 'type': 'inception', 'tail': '1921', 'meta': {'spans': [[122, 250]]}}, {'head': 'Irène Joliot-Curie', 'type': 'spouse', 'tail': 'Frédéric Joliot-Curie', 'meta': {'spans': [[244, 372]]}}, {'head': 'Frédéric Joliot-Curie', 'type': 'spouse', 'tail': 'Irène Joliot-Curie', 'meta': {'spans': [[244, 372]]}}, {'head': 'Irène Joliot-Curie', 'type': 'relative', 'tail': 'Frédéric Joliot-Curie', 'meta': {'spans': [[244, 372]]}}, {'head': 'Frédéric Joliot-Curie', 'type': 'relative', 'tail': 'Irène Joliot-Curie', 'meta': {'spans': [[244, 372]]}}, {'head': 'Ernest Rutherford', 'type': 'employer', 'tail': 'Cavendish Laboratory', 'meta': {'spans': [[366, 494]]}}, {'head': 'Otto Hahn', 'type': 'employer', 'tail': 'Kaiser Wilhelm Institute for Chemistry', 'meta': {'spans': [[366, 494]]}}, {'head': 'Stefan Meyer', 'type': 'employer', 'tail': 'Institute for Radium Research, Vienna', 'meta': {'spans': [[366, 494]]}}, {'head': 'Warsaw Radium Institute', 'type': 'inception', 'tail': '1932', 'meta': {'spans': [[488, 616]]}}, {'head': 'Radium Institute', 'type': 'inception', 'tail': '1932', 'meta': {'spans': [[488, 616]]}}, {'head': 'Radium Institute', 'type': 'located in the administrative territorial entity', 'tail': 'Warsaw', 'meta': {'spans': [[488, 616]]}}, {'head': 'Cameron Prize', 'type': 'conferred by', 'tail': 'University of Edinburgh', 'meta': {'spans': [[610, 738]]}}, {'head': 'Passy', 'type': 'located in the administrative territorial entity', 'tail': 'Haute-Savoie', 'meta': {'spans': [[610, 738]]}}, {'head': 'Haute-Savoie', 'type': 'contains administrative territorial entity', 'tail': 'Passy', 'meta': {'spans': [[610, 738]]}}, {'head': 'X-rays', 'type': 'has cause', 'tail': 'ionising radiation', 'meta': {'spans': [[732, 860]]}}, {'head': 'anemia', 'type': 'has cause', 'tail': "damage to Marie Curie's bone marrow", 'meta': {'spans': [[732, 860]]}}, {'head': "damage to Marie Curie's bone marrow", 'type': 'has effect', 'tail': 'anemia', 'meta': {'spans': [[732, 860]]}}, {'head': 'Marie Curie', 'type': 'conflict', 'tail': 'First World War', 'meta': {'spans': [[854, 982]]}}, {'head': 'Office de Protection contre les Rayonnements Ionisants', 'type': 'country', 'tail': 'French', 'meta': {'spans': [[854, 982]]}}, {'head': 'Sophie Berthelot', 'type': 'place of burial', 'tail': 'Paris Panthéon', 'meta': {'spans': [[976, 1104]]}}, {'head': 'Pierre', 'type': 'place of burial', 'tail': 'Paris Panthéon', 'meta': {'spans': [[976, 1104]]}}, {'head': 'Marie Curie', 'type': 'spouse', 'tail': 'Pierre', 'meta': {'spans': [[976, 1104]]}}, {'head': 'Pierre', 'type': 'spouse', 'tail': 'Marie Curie', 'meta': {'spans': [[976, 1104]]}}, {'head': 'Radioactivity', 'type': 'publication date', 'tail': '1935', 'meta': {'spans': [[1098, 1226]]}}, {'head': 'Radioactivity', 'type': 'author', 'tail': 'Marie Curie', 'meta': {'spans': [[1098, 1226]]}}, {'head': 'alpha radiation', 'type': 'discoverer or inventor', 'tail': 'Ernest Rutherford', 'meta': {'spans': [[1220, 1348]]}}, {'head': 'radium', 'type': 'discoverer or inventor', 'tail': 'Marie Curie', 'meta': {'spans': [[1220, 1348]]}}, {'head': 'nuclear atom', 'type': 'discoverer or inventor', 'tail': 'Ernest Rutherford', 'meta': {'spans': [[1220, 1348]]}}]
# KB saved to 'Marie Curie 6.pkl'
# Processed 'Marie Curie 6.docx' and saved KB.
# Text type: <class 'str'>
# Relations before saving: [{'head': 'Marie Curie', 'type': 'field of work', 'tail': 'physics', 'meta': {'spans': [[0, 128]]}}, {'head': 'Marie Curie', 'type': 'field of work', 'tail': 'chemistry', 'meta': {'spans': [[0, 128]]}}, {'head': 'physics', 'type': 'has part', 'tail': 'chemistry', 'meta': {'spans': [[0, 128]]}}, {'head': 'chemistry', 'type': 'part of', 'tail': 'physics', 'meta': {'spans': [[0, 128]]}}, {'head': 'Marie Curie', 'type': 'award received', 'tail': 'Nobel Prize', 'meta': {'spans': [[124, 252]]}}, {'head': 'Bust of "Maria Skłodowska-Curie", CERN Museum', 'type': 'country', 'tail': 'Switzerland', 'meta': {'spans': [[248, 376]]}}, {'head': 'Bust of "Maria Skłodowska-Curie", CERN Museum', 'type': 'depicts', 'tail': 'Marie Curie', 'meta': {'spans': [[248, 376]]}}, {'head': 'CERN Museum', 'type': 'country', 'tail': 'Switzerland', 'meta': {'spans': [[248, 376]]}}, {'head': 'Marie Curie', 'type': 'spouse', 'tail': 'Pierre Curie', 'meta': {'spans': [[372, 500], [496, 624]]}}, {'head': 'Pierre Curie', 'type': 'spouse', 'tail': 'Marie Curie', 'meta': {'spans': [[372, 500], [496, 624]]}}, {'head': 'Marie Curie', 'type': 'spouse', 'tail': 'Henri Becquerel', 'meta': {'spans': [[372, 500]]}}, {'head': 'Henri Becquerel', 'type': 'spouse', 'tail': 'Marie Curie', 'meta': {'spans': [[372, 500]]}}, {'head': 'curium', 'type': 'named after', 'tail': 'Marie Curie', 'meta': {'spans': [[496, 624]]}}, {'head': 'Order of the White Eagle', 'type': 'named after', 'tail': 'Marie Curie', 'meta': {'spans': [[496, 624]]}}, {'head': 'Marie Sklodowska-Curie Award', 'type': 'inception', 'tail': '2008', 'meta': {'spans': [[620, 748]]}}, {'head': 'Marie Sklodowska-Curie Award', 'type': 'conferred by', 'tail': 'Institute of Electrical and Electronics Engineers', 'meta': {'spans': [[620, 748]]}}, {'head': 'Marie Curie Medal', 'type': 'inception', 'tail': '1996', 'meta': {'spans': [[744, 872]]}}, {'head': 'Marie Curie Medal', 'type': 'conferred by', 'tail': 'Polish Chemical Society', 'meta': {'spans': [[744, 872]]}}, {'head': 'Marie Curie–Sklodowska Medal and Prize', 'type': 'inception', 'tail': '1996', 'meta': {'spans': [[744, 872]]}}, {'head': 'Marie Curie–Sklodowska Medal and Prize', 'type': 'conferred by', 'tail': 'Institute of Physics', 'meta': {'spans': [[744, 872]]}}, {'head': 'Institute of Physics', 'type': 'headquarters location', 'tail': 'London', 'meta': {'spans': [[744, 872]]}}, {'head': 'Maria Curie-Skłodowska University', 'type': 'located in the administrative territorial entity', 'tail': 'Lublin', 'meta': {'spans': [[744, 872]]}}, {'head': 'Pierre and Marie Curie University', 'type': 'located in the administrative territorial entity', 'tail': 'Paris', 'meta': {'spans': [[744, 872]]}}, {'head': 'École élémentaire Marie-Curie', 'type': 'located in the administrative', 'tail': 'London', 'meta': {'spans': [[744, 872]]}}, {'head': 'Marie Curie High School', 'type': 'located in the administrative territorial entity', 'tail': 'Ho Chi Minh City', 'meta': {'spans': [[868, 996]]}}, {'head': 'Marie Curie High School', 'type': 'country', 'tail': 'Vietnam', 'meta': {'spans': [[868, 996]]}}, {'head': 'Ho Chi Minh City', 'type': 'country', 'tail': 'Vietnam', 'meta': {'spans': [[868, 996]]}}, {'head': 'Vietnam', 'type': 'contains administrative territorial entity', 'tail': 'Ho Chi Minh City', 'meta': {'spans': [[868, 996]]}}, {'head': 'Lycée français Marie Curie de Zurich', 'type': 'country', 'tail': 'Switzerland', 'meta': {'spans': [[868, 996]]}}, {'head': 'Rue Madame Curie', 'type': 'located in the administrative territorial entity', 'tail': 'Beirut', 'meta': {'spans': [[868, 996]]}}, {'head': 'Rue Madame Curie', 'type': 'country', 'tail': 'Lebanon', 'meta': {'spans': [[868, 996]]}}, {'head': 'Beirut', 'type': 'country', 'tail': 'Lebanon', 'meta': {'spans': [[868, 996]]}}, {'head': 'Lycée Marie Curie', 'type': 'country', 'tail': 'Switzerland', 'meta': {'spans': [[868, 996]]}}, {'head': 'Chicago', 'type': 'country', 'tail': 'United States', 'meta':  ...
# KB saved to 'Marie Curie 7.pkl'
# Processed 'Marie Curie 7.docx' and saved KB.
# Text type: <class 'str'>
# Relations before saving: [{'head': '500-franc banknote', 'type': 'start time', 'tail': '1994', 'meta': {'spans': [[0, 128]]}}, {'head': '500-franc banknote', 'type': 'inception', 'tail': '1994', 'meta': {'spans': [[0, 128]]}}, {'head': '500-franc banknote', 'type': 'manufacturer', 'tail': 'Bank of France', 'meta': {'spans': [[0, 128]]}}, {'head': '500-franc banknote', 'type': 'depicts', 'tail': 'Marie Curie', 'meta': {'spans': [[0, 128]]}}, {'head': '500-franc banknote', 'type': 'depicts', 'tail': 'Pierre Curie', 'meta': {'spans': [[0, 128]]}}, {'head': 'Polonium', 'type': 'instance of', 'tail': 'chemical element', 'meta': {'spans': [[113, 241]]}}, {'head': 'Charlotte Hoffman Kellogg', 'type': 'country of citizenship', 'tail': 'United States', 'meta': {'spans': [[113, 241]]}}, {'head': 'Marie Curie', 'type': 'field of work', 'tail': 'chemistry', 'meta': {'spans': [[113, 241]]}}, {'head': 'Patricia Fara', 'type': 'employer', 'tail': 'University of Cambridge', 'meta': {'spans': [[226, 354]]}}, {'head': 'Making Marie Curie', 'type': 'author', 'tail': 'Eva Hemmungs Wirtén', 'meta': {'spans': [[226, 354]]}}, {'head': "Einstein's Fridge: The Science of Fire, Ice and the Universe", 'type': 'author', 'tail': 'Paul Sen', 'meta': {'spans': [[339, 467]]}}, {'head': 'Paul Sen', 'type': 'notable work', 'tail': "Einstein's Fridge: The Science of Fire, Ice and the Universe", 'meta': {'spans': [[339, 467]]}}, {'head': 'Curie', 'type': 'spouse', 'tail': 'Pierre', 'meta': {'spans': [[339, 467]]}}, {'head': 'Pierre', 'type': 'spouse', 'tail': 'Curie', 'meta': {'spans': [[339, 467]]}}]
# KB saved to 'Marie Curie 8.pkl'
# Processed 'Marie Curie 8.docx' and saved KB.

# %%
import stanza

# Initialize the Stanford NLP pipeline
stanza_nlp = stanza.Pipeline('en')

def extract_relations_with_stanza(text):
    doc = stanza_nlp(text)
    relations = []
    
    # Extract entities
    entities = {}
    for sentence in doc.sentences:
        for entity in sentence.ents:
            entities[entity.text] = entity.type
    
    # Extract relations using dependency parsing
    for sentence in doc.sentences:
        for word in sentence.words:
            if word.deprel == 'nsubj':  # Subject
                subject = word.text
                relation = next((w for w in sentence.words if w.head == word.id), None)
                if relation:
                    relation_type = relation.deprel
                    obj = next((w for w in sentence.words if w.head == relation.id), None)
                    if obj:
                        relations.append({
                            'head': subject,
                            'type': relation_type,
                            'tail': obj.text,
                            'meta': {'spans': []}  # Placeholder for span data
                        })
    
    return relations

def extend_kb_with_stanza(kb, text):
    relations = extract_relations_with_stanza(text)
    for relation in relations:
        kb.add_relation(relation)
    return kb
# Out:
# 2024-08-29 11:26:25 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-08-29 11:26:25 INFO: Downloaded file to C:\Users\ASUS\stanza_resources\resources.json
# 2024-08-29 11:26:26 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-08-29 11:26:26 INFO: Using device: cpu
# 2024-08-29 11:26:26 INFO: Loading: tokenize
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\tokenization\trainer.py:82: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-08-29 11:26:26 INFO: Loading: mwt
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\mwt\trainer.py:170: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-08-29 11:26:26 INFO: Loading: pos
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\pos\trainer.py:139: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\common\pretrain.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(self.filename, lambda storage, loc: storage)
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\common\char_model.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(filename, lambda storage, loc: storage)
# 2024-08-29 11:26:27 INFO: Loading: lemma
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\lemma\trainer.py:236: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-08-29 11:26:27 INFO: Loading: constituency
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\constituency\trainer.py:236: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-08-29 11:26:27 INFO: Loading: depparse
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\depparse\trainer.py:194: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-08-29 11:26:27 INFO: Loading: sentiment
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\classifiers\trainer.py:72: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-08-29 11:26:28 INFO: Loading: ner
# n:\Year 3\NLP\Assignment2\myenv\lib\site-packages\stanza\models\ner\trainer.py:197: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-08-29 11:26:28 INFO: Done loading processors!

# %%
def load_kb(file_path):
    # Assuming your KB is stored as a pickle file
    with open(file_path, 'rb') as f:
        kb = pickle.load(f)
    return kb

def saved_kb(kb, file_path):
    # Save the extended KB as a pickle file
    with open(file_path, 'wb') as f:
        pickle.dump(kb, f)

for i in range(1, 9):  # Assuming you have 8 text files
    # Load the text file from the temp_txt_files directory
    file_path = f"temp_txt_files/Marie Curie {i}.txt"
    with open(file_path, "r", encoding='utf-8', errors='ignore') as file:
        text = file.read()
        
        # Load the corresponding knowledge base (KB) from the saved_knowledge directory
        kb_path = f"Saved_Knowledge/Marie Curie {i}.pkl"
        kb = load_kb(kb_path)
        
        # Extend the KB using the Stanza processing method
        kb = extend_kb_with_stanza(kb, text)
        
        # Save the extended KB back to the saved_knowledge directory as a new .pkl file
        extended_kb_path = f"Saved_Knowledge/Marie Curie_Extended {i}.pkl"
        saved_kb(kb, extended_kb_path)
        
        # Optional: Print the KB (or any other desired output)
        print(f"KB {i} has been extended and saved to {extended_kb_path}.")
# Out:
# KB 1 has been extended and saved to Saved_Knowledge/Marie Curie_Extended 1.pkl.
# KB 2 has been extended and saved to Saved_Knowledge/Marie Curie_Extended 2.pkl.
# KB 3 has been extended and saved to Saved_Knowledge/Marie Curie_Extended 3.pkl.
# KB 4 has been extended and saved to Saved_Knowledge/Marie Curie_Extended 4.pkl.
# KB 5 has been extended and saved to Saved_Knowledge/Marie Curie_Extended 5.pkl.
# KB 6 has been extended and saved to Saved_Knowledge/Marie Curie_Extended 6.pkl.
# KB 7 has been extended and saved to Saved_Knowledge/Marie Curie_Extended 7.pkl.
# KB 8 has been extended and saved to Saved_Knowledge/Marie Curie_Extended 8.pkl.
